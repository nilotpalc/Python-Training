# %% [markdown]
# def add(n1=0,n2=0):
#     ''' Adds the 2 variables
#     n1+n2
#     '''
#     return n1+n2
#
# help(add)
#
# result = add(1,2)
#
# mylist = [1,2,3]
#
# <hr>
#
# def chk(hilist):
#     for item in enumerate(hilist):
#         return item
#
# abc = chk('string')
# abc
#
# <hr>
#
# def chk(hilist):
#     hello = []
#     for item in enumerate(hilist):
#         hello.append(item)
#     return hello
#
# abc = chk('string')
# abc
#
# <hr>
#
# for item in enumerate('string'):
#         print (item)
#
# def sdf(hilist):
#     for item in enumerate(hilist):
#         yield item
#
# for item in sdf('string'):
#     print (item)
#
# <hr>
#
# strin = 'I had zero'
#
# strin.split()
#
# <hr>
#
# def is_prime(num):
#     '''
#     Naive method of checking for primes.
#     '''
#     for n in range(2,num):
#         if num % n == 0:
#             print(num,'is not prime')
#             break
#     print(num,'is prime!')
#
# is_prime(29)
#
# str(3)
#
# <hr>
#
# import random
# s = randint(0,5)
# print (s)
#
# int(math.fsum([1,2,3]))
#
# hi = [2,3,4,5]
# random.shuffle(hi)
# list(hi)
